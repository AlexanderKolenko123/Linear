# %% [markdown]
# __1.__ Исследовать на линейную зависимость:
#
# $$f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}.$$

# %% [markdown]
# $$\alpha_{1}e^{x}+\alpha_{2}1+\alpha_{3}(x+1)+\alpha_{4}(x-e^{x})=0.$$

# %% [markdown]
# $$\begin{cases}
#  \alpha_{1}-\alpha_{4}=0,\\
#  \alpha_{3}+\alpha_{4}=0,\\
#  \alpha_{3}+\alpha_{2}=0,
# \end{cases}$$

# %% [markdown]
# $$f_{4}(x)=x-e^{x}=x+1+(-1)e^{x}+(-1)(1).$$-линейно зависимы.

# %% [markdown]
# __2.__ Исследовать на линейную зависимость:
# $$f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}$$

# %% [markdown]
# Если раскрыть скобки и составить систему уравнений то можно сделать вывод, что $$f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}$$ - линейно зависимы

# %% [markdown]
# __3.__ Найти координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.

# %% [markdown]
# Стандартный базис линейного пространства $\mathbb{R}^{3}$ образуют векторы
# $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.
# Тогда
#
# $$x=(2, 3, 5)=(0,0,20)+(6, 0, 0)+(0, 5, 0)=2\cdot(0, 0, 10)+3\cdot(2, 0, 0)+5\cdot(0, 1, 0)=1/2b_{1}+1b_{2}+3b_{3},$$

# %% [markdown]
# ##__4.__ Найти координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
#
# а) в базисе $1$, $x$, $x^{2}$;
#
# б) в базисе $x^{2}$, $x-1$, $1$.

# %% [markdown]
# а) (1/2,-2,3)

# %% [markdown]
# б)(3,-2,0)

# %% [markdown]
# ##__5.__ Установить, является ли линейным подпространством:
#
# а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
#
# б) все векторы, являющиеся линейными комбинациями данных векторов $\{u_{1}, u_{2}, \ldots, u_{n}\}$.

# %% [markdown]
# Не знаю

# %% [markdown]
# __1.__ Найти скалярное произведение векторов $x, y \in \mathbb{R}$:<br>
# а) $x=(0,-3, 6),~y=(-4, 7, 9);$<br>
# б) $x=(7, -4, 0, 1),~y=(-3, 1, 11, 2).$

# %%
import numpy as np

# %%
a = np.array([0, -3, 6])
b = np.array([-4, 7,9])
print(f'Скалярное произведение a и b:\n{np.dot(a, b)}')
print(f'Скалярное произведение a и b:\n{a.dot(b)}')
print(f'Скалярное произведение a и b:\n{a @ b}')
# Out:
# Скалярное произведение a и b:
# 33
# Скалярное произведение a и b:
# 33
# Скалярное произведение a и b:
# 33

# %%
a = np.array([7, -4, 0, 1])
b = np.array([-3, 1,11,2])
print(f'Скалярное произведение a и b:\n{np.dot(a, b)}')
print(f'Скалярное произведение a и b:\n{a.dot(b)}')
print(f'Скалярное произведение a и b:\n{a @ b}')
# Out:
# Скалярное произведение a и b:
# -23
# Скалярное произведение a и b:
# -23
# Скалярное произведение a и b:
# -23

# %% [markdown]
# __2.__ Найти нормы векторов $(4, 2, 4)$ и $(12, 3, 4)$ и угол между ними.

# %%
from numpy.linalg import norm

# %%
a = np.array([4, 2, 4])
b = np.array([12, 3, 4])

# %%
print(f'l1 Манхетовская норма вектора a:\n{norm(a, ord=1)}')
print(f'l1 Манхетовская норма вектора b:\n{norm(b, ord=1)}')
print(f'l2 Евклидова норма вектора а:\n{norm(a, ord=2)}')
print(f'l2 Евклидова норма вектора b:\n{norm(b, ord=2)}')
# Out:
# l1 Манхетовская норма вектора a:
# 10.0
# l1 Манхетовская норма вектора a:
# 19.0
# l2 Евклидова норма вектора а:
# 6.0
# l2 Евклидова норма вектора а:
# 13.0

# %%
cos_phi = np.dot(a, b) / norm(a) / norm(b)
cos_phi
# Out:
# 0.8974358974358974

# %% [markdown]
# __3.__ Будет ли линейное пространство евклидовым, если за скалярное произведение принять:<br>
# а) произведение длин векторов;<br>
# б) утроенное обычное скалярное произведение векторов?<br>

# %% [markdown]
# В случае А - пространство будет евклидовым/ В случае Б - нет/

# %% [markdown]
# __4.__ Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$:<br>
# а) $(1,0,0),(0,0,1);$ <br>
# б) $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>
# в) $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>
# г) $(1,0,0),(0,1,0),(0,0,1)?$

# %%
a = np.array([1, 0, 0])
b = np.array([0, 0, 1])
print(f'l1 Манхетовская норма вектора a:\n{norm(a, ord=1)}')
print(f'l1 Манхетовская норма вектора b:\n{norm(b, ord=1)}')
cos_phi = np.dot(a, b) / norm(a) / norm(b)
cos_phicos_phi = np.dot(a, b) / norm(a) / norm(b)
cos_phi
# Out:
# l1 Манхетовская норма вектора a:
# 1.0
# l1 Манхетовская норма вектора a:
# 1.0
# 0.0

# %%
a = np.array([1/2**(0.5), -1/2**(0.5), 0])
b = np.array([1/2**(0.5), 1/2**(0.5), 0])
c = np.array([0,0,1])
print(f'l1 Манхетовская норма вектора a:\n{norm(a, ord=1)}')
print(f'l1 Манхетовская норма вектора b:\n{norm(b, ord=1)}')
print(f'l1 Манхетовская норма вектора c:\n{norm(c, ord=1)}')
cos_phi_ab = np.dot(a, b) / norm(a) / norm(b)
cos_phi_ac = np.dot(a, c) / norm(a) / norm(b)
cos_phi_bc = np.dot(b, c) / norm(a) / norm(b)
print(cos_phi_ab)
print(cos_phi_ac)
print(cos_phi_bc)
# Out:
# l1 Манхетовская норма вектора a:
# 1.414213562373095
# l1 Манхетовская норма вектора b:
# 1.414213562373095
# l1 Манхетовская норма вектора c:
# 1.0
# 0.0
# 0.0
# 0.0

# %%
a = np.array([0.5, -0.5, 0])
b = np.array([0, 0.5, 0.5])
c = np.array([0, 0, 1])
print(f'l1 Манхетовская норма вектора a:\n{norm(a, ord=1)}')
print(f'l1 Манхетовская норма вектора b:\n{norm(b, ord=1)}')
print(f'l1 Манхетовская норма вектора c:\n{norm(c, ord=1)}')
cos_phi_ab = np.dot(a, b) / norm(a) / norm(b)
cos_phi_ac = np.dot(a, c) / norm(a) / norm(b)
cos_phi_bc = np.dot(b, c) / norm(a) / norm(b)
print(cos_phi_ab)
print(cos_phi_ac)
print(cos_phi_bc)
# Out:
# l1 Манхетовская норма вектора a:
# 1.0
# l1 Манхетовская норма вектора b:
# 1.0
# l1 Манхетовская норма вектора c:
# 1.0
# -0.49999999999999994
# 0.0
# 0.9999999999999999

# %%
a = np.array([1, 0, 0])
b = np.array([0, 1, 0])
c = np.array([0, 0, 1])
print(f'l1 Манхетовская норма вектора a:\n{norm(a, ord=1)}')
print(f'l1 Манхетовская норма вектора b:\n{norm(b, ord=1)}')
print(f'l1 Манхетовская норма вектора c:\n{norm(c, ord=1)}')
cos_phi_ab = np.dot(a, b) / norm(a) / norm(b)
cos_phi_ac = np.dot(a, c) / norm(a) / norm(b)
cos_phi_bc = np.dot(b, c) / norm(a) / norm(b)
print(cos_phi_ab)
print(cos_phi_ac)
print(cos_phi_bc)
# Out:
# l1 Манхетовская норма вектора a:
# 1.0
# l1 Манхетовская норма вектора b:
# 1.0
# l1 Манхетовская норма вектора c:
# 1.0
# 0.0
# 0.0
# 0.0

# %% [markdown]
# Все кроме В
